# %%
import pandas as pd
import sys
import os

utils_path = os.path.abspath('../dataset/Empty')
if utils_path not in sys.path:
    sys.path.append(utils_path)

from utils import *

# %%
file_path = '../dataset/Empty/101_DT_1JU1512_20250703031424.csv'
origin_df = pd.read_csv(file_path, encoding = 'cp949')

# %%
# df : 전처리된 df
df = preprocess_df(origin_df)

# %%
df
# Out:
#       행정구역별(시군구)        결합행정구역       주택의 종류별    항목  2022 년  2023 년
# 0          서울특별시         서울특별시             계  주택_계  100706  107681
# 20         서울특별시         서울특별시          단독주택  주택_계    3299    4270
# 40         서울특별시         서울특별시           아파트  주택_계   53654   55087
# 60         서울특별시         서울특별시          연립주택  주택_계    5922    6537
# 80         서울특별시         서울특별시         다세대주택  주택_계   36317   40183
# ...          ...           ...           ...   ...     ...     ...
# 33614       서귀포시  제주특별자치도 서귀포시          단독주택  주택_계    3463    3812
# 33634       서귀포시  제주특별자치도 서귀포시           아파트  주택_계    2775    3136
# 33654       서귀포시  제주특별자치도 서귀포시          연립주택  주택_계    3215    3433
# 33674       서귀포시  제주특별자치도 서귀포시         다세대주택  주택_계    1763    1865
# 33694       서귀포시  제주특별자치도 서귀포시  비주거용 건물 내 주택  주택_계     268     271
#
# [1674 rows x 6 columns]

# %%
# 상위 레벨 행정구역의 미거주 주택수
sum_df = sum_upper_region(df)

# %%
sum_df
# Out:
#    행정구역별(시군구)   결합행정구역 주택의 종류별    항목  2022 년  2023 년
# 0       서울특별시    서울특별시       계  주택_계  100706  107681
# 1       부산광역시    부산광역시       계  주택_계  110500  114245
# 2       대구광역시    대구광역시       계  주택_계   43086   56673
# 3       인천광역시    인천광역시       계  주택_계   72036   84414
# 4       광주광역시    광주광역시       계  주택_계   39205   40588
# 5       대전광역시    대전광역시       계  주택_계   26262   25396
# 6       울산광역시    울산광역시       계  주택_계   29569   30900
# 7     세종특별자치시  세종특별자치시       계  주택_계   12388   13019
# 8         경기도      경기도       계  주택_계  262266  286140
# 9     강원특별자치도  강원특별자치도       계  주택_계   80609   82552
# 10       충청북도     충청북도       계  주택_계   68843   71302
# 11       충청남도     충청남도       계  주택_계  101637  113209
# 12       전라북도     전라북도       계  주택_계   90190   90842
# 13       전라남도     전라남도       계  주택_계  119711  121232
# 14       경상북도     경상북도       계  주택_계  127459  129041
# 15       경상남도     경상남도       계  주택_계  134925  132798
# 16    제주특별자치도  제주특별자치도       계  주택_계   32162   34887

# %%
fig = plot_empty_upper(sum_df, title ='상위행정구역별_빈집_수' ,save=True)
fig.show()
# Out:
# ✅ 그래프가 HTML로 저장되었습니다: ./plot/상위행정구역별_빈집_수.html

# %%
# png 출력용 - 깃에서 보기위함
pio.show(fig, renderer="png")

# %%
# sub_df 하위 행정구역 단위 데이터
sub_df = df[df['행정구역별(시군구)']!=df['결합행정구역']]
sub_df['2023 년'] = pd.to_numeric(sub_df['2023 년'], errors='coerce')
sub_df_sorted = sub_df.sort_values(by='2023 년', ascending=False)
# Out:
# /var/folders/6m/0y3_kg5x2sx85_03lp89vlt80000gn/T/ipykernel_6960/86922649.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
filter_df = sub_df_sorted[sub_df_sorted['주택의 종류별']=='계'].head(10)
filter_df
# Out:
#       행정구역별(시군구)       결합행정구역 주택의 종류별    항목 2022 년   2023 년
# 12240        평택시      경기도 평택시       계  주택_계  30314  32009.0
# 18840        청주시     충청북도 청주시       계  주택_계  24312  25668.0
# 31434        창원시     경상남도 창원시       계  주택_계  25477  23794.0
# 15240        화성시      경기도 화성시       계  주택_계  23902  23201.0
# 33474        제주시  제주특별자치도 제주시       계  주택_계  20678  22370.0
# 20520        천안시     충청남도 천안시       계  주택_계  20139  21712.0
# 27480        포항시     경상북도 포항시       계  주택_계  19996  21180.0
# 21120        아산시     충청남도 아산시       계  주택_계  16014  20598.0
# 22680        전주시     전라북도 전주시       계  주택_계  20238  19471.0
# 23040        군산시     전라북도 군산시       계  주택_계  18331  18335.0

# %%
fig = plot_empty_upper(filter_df, title='하위 행정구역별 빈집 수(상위 10개)', save=False)
fig.show()

# %%
# png 출력용 - 깃에서 보기위함
pio.show(fig, renderer="png")

# %%
fig = plot_bar_by_house_type_split_by_year(df)
fig.show()
# Out:
# ✅ 그래프가 HTML로 저장되었습니다: ./plot/상위 10개 지역(2023년 기준)의 주택 유형별 주택 수.html

# %%
# png 출력용 - 깃에서 보기위함
pio.show(fig, renderer="png")

# %% [markdown]
# ### custom 폐가지수
# - 단독주택, 다세대주택만 고려
# - min-max scaling
# - 0.7* 단독주택 + 0.3 * 다세대주택

# %%
df = df[df['행정구역별(시군구)'] != df['결합행정구역']]
df = df[df['주택의 종류별'].isin(['단독주택', '다세대주택'])].reset_index(drop=True)


df.reset_index(drop=True, inplace=True)
df
# Out:
#     행정구역별(시군구)        결합행정구역 주택의 종류별    항목 2022 년 2023 년
# 0          종로구     서울특별시 종로구    단독주택  주택_계    212    243
# 1          종로구     서울특별시 종로구   다세대주택  주택_계    705    775
# 2           중구      서울특별시 중구    단독주택  주택_계     35     49
# 3           중구      서울특별시 중구   다세대주택  주택_계    471    179
# 4          용산구     서울특별시 용산구    단독주택  주택_계    142    324
# ..         ...           ...     ...   ...    ...    ...
# 519        합천군      경상남도 합천군   다세대주택  주택_계     81     76
# 520        제주시   제주특별자치도 제주시    단독주택  주택_계   6568   7418
# 521        제주시   제주특별자치도 제주시   다세대주택  주택_계   4791   5103
# 522       서귀포시  제주특별자치도 서귀포시    단독주택  주택_계   3463   3812
# 523       서귀포시  제주특별자치도 서귀포시   다세대주택  주택_계   1763   1865
#
# [524 rows x 6 columns]

# %%
# 연도별 폐가지수를 계산 (예: 2023년 기준)
pivot_df = df.pivot(index='결합행정구역', columns='주택의 종류별', values='2023 년')

# 결측값 처리 (빈집 수가 없으면 0으로 간주)
pivot_df = pivot_df.fillna(0)

# %%
# 변환 대상 열 지정
columns_to_convert = ['단독주택', '다세대주택']

# 변환 수행
for col in columns_to_convert:
    pivot_df[col] = (
        pivot_df[col]
        .astype(str)                    
        .str.replace(',', '', regex=False)  
        .str.strip()                     
    )
    pivot_df[col] = pd.to_numeric(pivot_df[col], errors='coerce').fillna(0)

pivot_df['폐가지수_2023_raw'] = pivot_df['단독주택'] * 0.6 + pivot_df['다세대주택'] * 0.4
  

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
pivot_df['폐가지수_2023'] = scaler.fit_transform(pivot_df[['폐가지수_2023_raw']])

# %%
pivot_df['폐가지수_2023_순위'] = pivot_df['폐가지수_2023'].rank(ascending=False, method='min')

pivot_df = pivot_df.sort_values('폐가지수_2023_순위')

# %%
pivot_df.reset_index(inplace=True)

# %%
pivot_df
# Out:
# 주택의 종류별        결합행정구역   다세대주택    단독주택  폐가지수_2023_raw  폐가지수_2023  폐가지수_2023_순위
# 0         제주특별자치도 제주시  5103.0  7418.0         6492.0   1.000000           1.0
# 1             경기도 평택시  7439.0  2049.0         4205.0   0.647720           2.0
# 2            경상북도 경주시   866.0  5672.0         3749.6   0.577572           3.0
# 3            부산광역시 남구  4419.0  3281.0         3736.2   0.575508           4.0
# 4            경상남도 창원시   822.0  5494.0         3625.2   0.558410           5.0
# ..                ...     ...     ...            ...        ...           ...
# 257       경기도 용인시 수지구   114.0    32.0           64.8   0.009982         258.0
# 258       경기도 성남시 분당구    71.0    21.0           41.0   0.006315         259.0
# 259       강원특별자치도 양구군    19.0    27.0           23.8   0.003666         260.0
# 260      경상남도 창원시 성산구     0.0    23.0           13.8   0.002126         261.0
# 261          경상북도 군위군     0.0     0.0            0.0   0.000000         262.0
#
# [262 rows x 6 columns]

# %%
import plotly.express as px

fig = px.bar(
    pivot_df,
    x='결합행정구역',
    y='폐가지수_2023',
    title='결합 행정구역별 폐가지수_2023',
    labels={'결합행정구역': '결합 행정구역', '폐가지수_2023': '폐가지수 (2023)'},
)

fig.update_layout(xaxis_tickangle=-45)  # x축 라벨 기울이기
fig.show()
save_fig_to_html(fig, './plot/폐가수.html')
# Out:
# ✅ 그래프가 HTML로 저장되었습니다: ./plot/폐가수.html

# %%
pio.show(fig, renderer="png")

# %%
empty_df = pivot_df[['결합행정구역', '다세대주택','단독주택','폐가지수_2023_raw','폐가지수_2023']]
empty_df.columns = ['행정구역','다세대주택','단독주택', '폐가지수', '페가지수_scaled']
empty_df['연도'] = 2023

empty_df = empty_df.sort_values(by='행정구역')
empty_df.reset_index(drop=True, inplace=True)

# %%
empty_df = merge_by_province_city(empty_df)

# %%
empty_df.to_csv('./ref_dataset/02_폐가지수.csv')
